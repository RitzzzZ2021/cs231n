# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs231n/assignment1/cs231n/datasets
# /content/drive/My Drive/cs231n/assignment1

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)
# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.354230
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ The output of softmax function is supposed to be 0.1, because the number of classes is 10 and the probability of certain class is 0.1.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.371836 analytic: 0.371836, relative error: 9.587717e-08
# numerical: -2.729544 analytic: -2.729544, relative error: 3.943496e-09
# numerical: 0.219097 analytic: 0.219097, relative error: 7.269134e-08
# numerical: -0.054734 analytic: -0.054734, relative error: 8.832529e-07
# numerical: -2.175974 analytic: -2.175974, relative error: 4.138188e-10
# numerical: 0.962922 analytic: 0.962922, relative error: 4.280606e-08
# numerical: -1.233443 analytic: -1.233443, relative error: 2.549200e-08
# numerical: -0.301421 analytic: -0.301421, relative error: 6.172608e-08
# numerical: 1.015456 analytic: 1.015456, relative error: 3.527762e-08
# numerical: 4.382242 analytic: 4.382242, relative error: 1.637972e-08
# numerical: 0.020456 analytic: 0.020456, relative error: 6.622156e-07
# numerical: 0.016101 analytic: 0.016101, relative error: 1.567930e-06
# numerical: 1.345355 analytic: 1.345355, relative error: 2.213636e-08
# numerical: 0.188964 analytic: 0.188964, relative error: 1.453700e-07
# numerical: -2.397528 analytic: -2.397528, relative error: 3.673433e-09
# numerical: 1.411952 analytic: 1.411952, relative error: 6.301719e-09
# numerical: -0.139425 analytic: -0.139425, relative error: 1.841689e-07
# numerical: 0.035703 analytic: 0.035704, relative error: 1.167816e-06
# numerical: 1.567359 analytic: 1.567359, relative error: 6.169950e-08
# numerical: -2.725403 analytic: -2.725403, relative error: 1.095285e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.354230e+00 computed in 0.178322s
# vectorized loss: 2.354230e+00 computed in 0.018842s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

lr_ = learning_rates[0]
while(lr_ <= learning_rates[1]):
  reg_ = regularization_strengths[0]
  while(reg_ <= regularization_strengths[1]):
    softmax = Softmax()
    loss_hist = softmax.train(X_train, y_train, learning_rate=lr_, reg=reg_,
                      num_iters=500, verbose=True)
    y_t_pred = softmax.predict(X_train)
    t_accuracy = np.mean(y_train == y_t_pred)
    y_val_pred = softmax.predict(X_val)
    v_accuracy = np.mean(y_val == y_val_pred)
    results[(lr_, reg_)] = (t_accuracy, v_accuracy)
    if v_accuracy > best_val:
      best_val = v_accuracy
      best_lr = lr_
      best_reg = reg_
    reg_ += 1e3
  lr_ += 1e-7

best_softmax = Softmax()
loss_hist = best_softmax.train(X_train, y_train, learning_rate=best_lr, reg=best_reg,
                      num_iters=1500, verbose=True)
y_val_pred = best_softmax.predict(X_val)
best_val = np.mean(y_val == y_val_pred)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 500: loss 392.974665
# iteration 100 / 500: loss 237.605435
# iteration 200 / 500: loss 144.049374
# iteration 300 / 500: loss 87.915780
# iteration 400 / 500: loss 53.943350
# iteration 0 / 500: loss 404.230512
# iteration 100 / 500: loss 239.971542
# iteration 200 / 500: loss 142.966495
# iteration 300 / 500: loss 85.404396
# iteration 400 / 500: loss 51.465428
# iteration 0 / 500: loss 415.387897
# iteration 100 / 500: loss 241.713171
# iteration 200 / 500: loss 141.000451
# iteration 300 / 500: loss 82.640792
# iteration 400 / 500: loss 48.828564
# iteration 0 / 500: loss 433.176475
# iteration 100 / 500: loss 247.177107
# iteration 200 / 500: loss 141.601956
# iteration 300 / 500: loss 81.326507
# iteration 400 / 500: loss 47.168202
# iteration 0 / 500: loss 445.377138
# iteration 100 / 500: loss 248.787456
# iteration 200 / 500: loss 139.537457
# iteration 300 / 500: loss 78.769949
# iteration 400 / 500: loss 44.878247
# iteration 0 / 500: loss 467.804705
# iteration 100 / 500: loss 255.673891
# iteration 200 / 500: loss 140.879442
# iteration 300 / 500: loss 77.909092
# iteration 400 / 500: loss 43.630406
# iteration 0 / 500: loss 479.290550
# iteration 100 / 500: loss 256.761073
# iteration 200 / 500: loss 138.432417
# iteration 300 / 500: loss 75.170781
# iteration 400 / 500: loss 41.286972
# iteration 0 / 500: loss 499.343701
# iteration 100 / 500: loss 262.757320
# iteration 200 / 500: loss 138.911988
# iteration 300 / 500: loss 73.940188
# iteration 400 / 500: loss 39.784060
# iteration 0 / 500: loss 510.584925
# iteration 100 / 500: loss 263.564221
# iteration 200 / 500: loss 136.516589
# iteration 300 / 500: loss 71.435575
# iteration 400 / 500: loss 37.660670
# iteration 0 / 500: loss 528.046345
# iteration 100 / 500: loss 267.121717
# iteration 200 / 500: loss 135.721681
# iteration 300 / 500: loss 69.497196
# iteration 400 / 500: loss 36.107453
# iteration 0 / 500: loss 552.944775
# iteration 100 / 500: loss 273.729316
# iteration 200 / 500: loss 136.309906
# iteration 300 / 500: loss 68.545057
# iteration 400 / 500: loss 34.919779
# iteration 0 / 500: loss 565.469716
# iteration 100 / 500: loss 274.441916
# iteration 200 / 500: loss 133.990422
# iteration 300 / 500: loss 66.117868
# iteration 400 / 500: loss 33.025478
# iteration 0 / 500: loss 572.938061
# iteration 100 / 500: loss 272.464168
# iteration 200 / 500: loss 130.432329
# iteration 300 / 500: loss 63.146321
# iteration 400 / 500: loss 31.113406
# iteration 0 / 500: loss 584.327657
# iteration 100 / 500: loss 272.723477
# iteration 200 / 500: loss 128.224697
# iteration 300 / 500: loss 60.850458
# iteration 400 / 500: loss 29.421059
# iteration 0 / 500: loss 603.177759
# iteration 100 / 500: loss 275.747802
# iteration 200 / 500: loss 126.854482
# iteration 300 / 500: loss 59.079570
# iteration 400 / 500: loss 28.121344
# iteration 0 / 500: loss 622.606343
# iteration 100 / 500: loss 279.040363
# iteration 200 / 500: loss 125.849932
# iteration 300 / 500: loss 57.481351
# iteration 400 / 500: loss 26.805388
# iteration 0 / 500: loss 632.513648
# iteration 100 / 500: loss 277.763523
# iteration 200 / 500: loss 122.979306
# iteration 300 / 500: loss 55.043039
# iteration 400 / 500: loss 25.372966
# iteration 0 / 500: loss 657.362484
# iteration 100 / 500: loss 283.351735
# iteration 200 / 500: loss 123.017862
# iteration 300 / 500: loss 53.980143
# iteration 400 / 500: loss 24.378418
# iteration 0 / 500: loss 664.670505
# iteration 100 / 500: loss 280.608855
# iteration 200 / 500: loss 119.355961
# iteration 300 / 500: loss 51.455331
# iteration 400 / 500: loss 22.864767
# iteration 0 / 500: loss 687.329848
# iteration 100 / 500: loss 284.320695
# iteration 200 / 500: loss 118.414978
# iteration 300 / 500: loss 50.128425
# iteration 400 / 500: loss 21.940647
# iteration 0 / 500: loss 698.094851
# iteration 100 / 500: loss 282.588615
# iteration 200 / 500: loss 115.508532
# iteration 300 / 500: loss 48.026423
# iteration 400 / 500: loss 20.643798
# iteration 0 / 500: loss 708.624967
# iteration 100 / 500: loss 281.707698
# iteration 200 / 500: loss 112.981521
# iteration 300 / 500: loss 46.060084
# iteration 400 / 500: loss 19.560228
# iteration 0 / 500: loss 720.485509
# iteration 100 / 500: loss 280.052620
# iteration 200 / 500: loss 110.139538
# iteration 300 / 500: loss 44.036650
# iteration 400 / 500: loss 18.428660
# iteration 0 / 500: loss 745.422960
# iteration 100 / 500: loss 284.097569
# iteration 200 / 500: loss 109.394778
# iteration 300 / 500: loss 43.030655
# iteration 400 / 500: loss 17.619502
# iteration 0 / 500: loss 750.630018
# iteration 100 / 500: loss 280.559394
# iteration 200 / 500: loss 105.911463
# iteration 300 / 500: loss 40.814355
# iteration 400 / 500: loss 16.530521
# iteration 0 / 500: loss 768.233226
# iteration 100 / 500: loss 282.029352
# iteration 200 / 500: loss 104.517268
# iteration 300 / 500: loss 39.565784
# iteration 400 / 500: loss 15.841023
# iteration 0 / 500: loss 394.297561
# iteration 100 / 500: loss 144.184240
# iteration 200 / 500: loss 54.015014
# iteration 300 / 500: loss 21.067202
# iteration 400 / 500: loss 8.907742
# iteration 0 / 500: loss 400.948437
# iteration 100 / 500: loss 141.748984
# iteration 200 / 500: loss 50.998966
# iteration 300 / 500: loss 19.251098
# iteration 400 / 500: loss 8.046353
# iteration 0 / 500: loss 423.468440
# iteration 100 / 500: loss 143.495741
# iteration 200 / 500: loss 49.748006
# iteration 300 / 500: loss 18.089490
# iteration 400 / 500: loss 7.440974
# iteration 0 / 500: loss 445.058199
# iteration 100 / 500: loss 145.065370
# iteration 200 / 500: loss 48.182621
# iteration 300 / 500: loss 17.004133
# iteration 400 / 500: loss 6.811286
# iteration 0 / 500: loss 456.941549
# iteration 100 / 500: loss 142.863004
# iteration 200 / 500: loss 45.827553
# iteration 300 / 500: loss 15.629567
# iteration 400 / 500: loss 6.359925
# iteration 0 / 500: loss 463.977444
# iteration 100 / 500: loss 139.628679
# iteration 200 / 500: loss 43.091379
# iteration 300 / 500: loss 14.343211
# iteration 400 / 500: loss 5.734940
# iteration 0 / 500: loss 482.467523
# iteration 100 / 500: loss 139.387571
# iteration 200 / 500: loss 41.458030
# iteration 300 / 500: loss 13.457934
# iteration 400 / 500: loss 5.309018
# iteration 0 / 500: loss 496.188279
# iteration 100 / 500: loss 137.591588
# iteration 200 / 500: loss 39.407558
# iteration 300 / 500: loss 12.384490
# iteration 400 / 500: loss 4.901764
# iteration 0 / 500: loss 513.207041
# iteration 100 / 500: loss 136.781105
# iteration 200 / 500: loss 37.803768
# iteration 300 / 500: loss 11.533609
# iteration 400 / 500: loss 4.511099
# iteration 0 / 500: loss 535.815739
# iteration 100 / 500: loss 137.379794
# iteration 200 / 500: loss 36.403467
# iteration 300 / 500: loss 10.800382
# iteration 400 / 500: loss 4.240459
# iteration 0 / 500: loss 547.086627
# iteration 100 / 500: loss 134.822333
# iteration 200 / 500: loss 34.428540
# iteration 300 / 500: loss 9.992386
# iteration 400 / 500: loss 3.986070
# iteration 0 / 500: loss 559.251863
# iteration 100 / 500: loss 131.882799
# iteration 200 / 500: loss 32.482423
# iteration 300 / 500: loss 9.283235
# iteration 400 / 500: loss 3.782559
# iteration 0 / 500: loss 574.329748
# iteration 100 / 500: loss 130.732902
# iteration 200 / 500: loss 31.030903
# iteration 300 / 500: loss 8.539554
# iteration 400 / 500: loss 3.553580
# iteration 0 / 500: loss 591.248776
# iteration 100 / 500: loss 129.148548
# iteration 200 / 500: loss 29.607216
# iteration 300 / 500: loss 8.007138
# iteration 400 / 500: loss 3.394743
# iteration 0 / 500: loss 612.725657
# iteration 100 / 500: loss 128.699546
# iteration 200 / 500: loss 28.371363
# iteration 300 / 500: loss 7.418241
# iteration 400 / 500: loss 3.213272
# iteration 0 / 500: loss 607.675709
# iteration 100 / 500: loss 122.579025
# iteration 200 / 500: loss 26.100968
# iteration 300 / 500: loss 6.863716
# iteration 400 / 500: loss 3.065788
# iteration 0 / 500: loss 636.953775
# iteration 100 / 500: loss 123.422282
# iteration 200 / 500: loss 25.354907
# iteration 300 / 500: loss 6.464991
# iteration 400 / 500: loss 2.969895
# iteration 0 / 500: loss 644.097839
# iteration 100 / 500: loss 119.986650
# iteration 200 / 500: loss 23.818689
# iteration 300 / 500: loss 6.072648
# iteration 400 / 500: loss 2.763570
# iteration 0 / 500: loss 664.874173
# iteration 100 / 500: loss 118.943288
# iteration 200 / 500: loss 22.771659
# iteration 300 / 500: loss 5.716699
# iteration 400 / 500: loss 2.795965
# iteration 0 / 500: loss 682.760599
# iteration 100 / 500: loss 117.561620
# iteration 200 / 500: loss 21.698220
# iteration 300 / 500: loss 5.391943
# iteration 400 / 500: loss 2.645065
# iteration 0 / 500: loss 701.032770
# iteration 100 / 500: loss 115.716421
# iteration 200 / 500: loss 20.631460
# iteration 300 / 500: loss 5.086977
# iteration 400 / 500: loss 2.543607
# iteration 0 / 500: loss 721.236775
# iteration 100 / 500: loss 114.489261
# iteration 200 / 500: loss 19.684503
# iteration 300 / 500: loss 4.832399
# iteration 400 / 500: loss 2.497490
# iteration 0 / 500: loss 726.121234
# iteration 100 / 500: loss 110.763794
# iteration 200 / 500: loss 18.418857
# iteration 300 / 500: loss 4.533974
# iteration 400 / 500: loss 2.486644
# iteration 0 / 500: loss 750.999224
# iteration 100 / 500: loss 109.816998
# iteration 200 / 500: loss 17.636457
# iteration 300 / 500: loss 4.332737
# iteration 400 / 500: loss 2.415947
# iteration 0 / 500: loss 762.744470
# iteration 100 / 500: loss 107.408959
# iteration 200 / 500: loss 16.690981
# iteration 300 / 500: loss 4.095718
# iteration 400 / 500: loss 2.390881
# iteration 0 / 500: loss 783.966647
# iteration 100 / 500: loss 106.139971
# iteration 200 / 500: loss 15.968161
# iteration 300 / 500: loss 3.980314
# iteration 400 / 500: loss 2.333778
# iteration 0 / 500: loss 388.713586
# iteration 100 / 500: loss 87.084434
# iteration 200 / 500: loss 20.707506
# iteration 300 / 500: loss 6.257224
# iteration 400 / 500: loss 3.004551
# iteration 0 / 500: loss 404.899609
# iteration 100 / 500: loss 85.143609
# iteration 200 / 500: loss 19.239531
# iteration 300 / 500: loss 5.605984
# iteration 400 / 500: loss 2.788067
# iteration 0 / 500: loss 418.998080
# iteration 100 / 500: loss 83.337370
# iteration 200 / 500: loss 17.923429
# iteration 300 / 500: loss 5.144120
# iteration 400 / 500: loss 2.552493
# iteration 0 / 500: loss 440.917126
# iteration 100 / 500: loss 82.063707
# iteration 200 / 500: loss 16.744709
# iteration 300 / 500: loss 4.765973
# iteration 400 / 500: loss 2.511148
# iteration 0 / 500: loss 450.638733
# iteration 100 / 500: loss 79.079765
# iteration 200 / 500: loss 15.431839
# iteration 300 / 500: loss 4.321014
# iteration 400 / 500: loss 2.468027
# iteration 0 / 500: loss 474.885175
# iteration 100 / 500: loss 78.790861
# iteration 200 / 500: loss 14.506767
# iteration 300 / 500: loss 4.006333
# iteration 400 / 500: loss 2.341145
# iteration 0 / 500: loss 485.256859
# iteration 100 / 500: loss 75.515524
# iteration 200 / 500: loss 13.354320
# iteration 300 / 500: loss 3.861619
# iteration 400 / 500: loss 2.283498
# iteration 0 / 500: loss 500.768729
# iteration 100 / 500: loss 73.741744
# iteration 200 / 500: loss 12.419275
# iteration 300 / 500: loss 3.518361
# iteration 400 / 500: loss 2.278533
# iteration 0 / 500: loss 509.941753
# iteration 100 / 500: loss 70.671444
# iteration 200 / 500: loss 11.422854
# iteration 300 / 500: loss 3.315227
# iteration 400 / 500: loss 2.156006
# iteration 0 / 500: loss 520.974280
# iteration 100 / 500: loss 67.929805
# iteration 200 / 500: loss 10.482941
# iteration 300 / 500: loss 3.153989
# iteration 400 / 500: loss 2.213983
# iteration 0 / 500: loss 543.177198
# iteration 100 / 500: loss 66.963921
# iteration 200 / 500: loss 9.814513
# iteration 300 / 500: loss 2.973172
# iteration 400 / 500: loss 2.136865
# iteration 0 / 500: loss 558.180331
# iteration 100 / 500: loss 64.760632
# iteration 200 / 500: loss 9.173550
# iteration 300 / 500: loss 2.882373
# iteration 400 / 500: loss 2.121898
# iteration 0 / 500: loss 573.661022
# iteration 100 / 500: loss 62.816079
# iteration 200 / 500: loss 8.593778
# iteration 300 / 500: loss 2.763893
# iteration 400 / 500: loss 2.211391
# iteration 0 / 500: loss 591.893015
# iteration 100 / 500: loss 61.022089
# iteration 200 / 500: loss 8.029150
# iteration 300 / 500: loss 2.660101
# iteration 400 / 500: loss 2.127980
# iteration 0 / 500: loss 593.923714
# iteration 100 / 500: loss 57.727493
# iteration 200 / 500: loss 7.370696
# iteration 300 / 500: loss 2.520261
# iteration 400 / 500: loss 2.074634
# iteration 0 / 500: loss 623.205744
# iteration 100 / 500: loss 56.898464
# iteration 200 / 500: loss 6.971538
# iteration 300 / 500: loss 2.497239
# iteration 400 / 500: loss 2.127586
# iteration 0 / 500: loss 633.529487
# iteration 100 / 500: loss 54.481693
# iteration 200 / 500: loss 6.422900
# iteration 300 / 500: loss 2.506808
# iteration 400 / 500: loss 2.118922
# iteration 0 / 500: loss 647.303334
# iteration 100 / 500: loss 52.686968
# iteration 200 / 500: loss 6.043691
# iteration 300 / 500: loss 2.355580
# iteration 400 / 500: loss 2.061059
# iteration 0 / 500: loss 665.393992
# iteration 100 / 500: loss 50.878743
# iteration 200 / 500: loss 5.675275
# iteration 300 / 500: loss 2.366808
# iteration 400 / 500: loss 2.084984
# iteration 0 / 500: loss 674.406941
# iteration 100 / 500: loss 48.818454
# iteration 200 / 500: loss 5.378724
# iteration 300 / 500: loss 2.290596
# iteration 400 / 500: loss 2.128958
# iteration 0 / 500: loss 694.933065
# iteration 100 / 500: loss 47.362058
# iteration 200 / 500: loss 5.098497
# iteration 300 / 500: loss 2.297079
# iteration 400 / 500: loss 2.065466
# iteration 0 / 500: loss 706.190013
# iteration 100 / 500: loss 45.285776
# iteration 200 / 500: loss 4.736893
# iteration 300 / 500: loss 2.244149
# iteration 400 / 500: loss 2.124109
# iteration 0 / 500: loss 719.583708
# iteration 100 / 500: loss 43.639432
# iteration 200 / 500: loss 4.473244
# iteration 300 / 500: loss 2.280714
# iteration 400 / 500: loss 2.046125
# iteration 0 / 500: loss 742.980977
# iteration 100 / 500: loss 42.541363
# iteration 200 / 500: loss 4.261736
# iteration 300 / 500: loss 2.208100
# iteration 400 / 500: loss 2.048510
# iteration 0 / 500: loss 766.793302
# iteration 100 / 500: loss 41.197358
# iteration 200 / 500: loss 4.120848
# iteration 300 / 500: loss 2.230015
# iteration 400 / 500: loss 2.134321
# iteration 0 / 500: loss 764.858201
# iteration 100 / 500: loss 38.795826
# iteration 200 / 500: loss 3.867729
# iteration 300 / 500: loss 2.168290
# iteration 400 / 500: loss 2.100959
# iteration 0 / 500: loss 394.168933
# iteration 100 / 500: loss 53.669428
# iteration 200 / 500: loss 8.957049
# iteration 300 / 500: loss 2.957043
# iteration 400 / 500: loss 2.152030
# iteration 0 / 500: loss 406.179093
# iteration 100 / 500: loss 51.192240
# iteration 200 / 500: loss 8.068766
# iteration 300 / 500: loss 2.777701
# iteration 400 / 500: loss 2.113571
# iteration 0 / 500: loss 421.290214
# iteration 100 / 500: loss 49.236563
# iteration 200 / 500: loss 7.437938
# iteration 300 / 500: loss 2.682364
# iteration 400 / 500: loss 2.208532
# iteration 0 / 500: loss 438.129507
# iteration 100 / 500: loss 47.161183
# iteration 200 / 500: loss 6.794511
# iteration 300 / 500: loss 2.532162
# iteration 400 / 500: loss 2.092831
# iteration 0 / 500: loss 453.760115
# iteration 100 / 500: loss 45.196282
# iteration 200 / 500: loss 6.148284
# iteration 300 / 500: loss 2.468423
# iteration 400 / 500: loss 2.072420
# iteration 0 / 500: loss 473.976716
# iteration 100 / 500: loss 43.686799
# iteration 200 / 500: loss 5.749112
# iteration 300 / 500: loss 2.434706
# iteration 400 / 500: loss 2.057312
# iteration 0 / 500: loss 484.521679
# iteration 100 / 500: loss 41.360801
# iteration 200 / 500: loss 5.251825
# iteration 300 / 500: loss 2.295410
# iteration 400 / 500: loss 2.085536
# iteration 0 / 500: loss 494.293468
# iteration 100 / 500: loss 39.046461
# iteration 200 / 500: loss 4.825471
# iteration 300 / 500: loss 2.299941
# iteration 400 / 500: loss 2.001009
# iteration 0 / 500: loss 506.370840
# iteration 100 / 500: loss 36.895586
# iteration 200 / 500: loss 4.498662
# iteration 300 / 500: loss 2.231888
# iteration 400 / 500: loss 2.037483
# iteration 0 / 500: loss 525.525141
# iteration 100 / 500: loss 35.492265
# iteration 200 / 500: loss 4.154471
# iteration 300 / 500: loss 2.282330
# iteration 400 / 500: loss 2.126430
# iteration 0 / 500: loss 546.632201
# iteration 100 / 500: loss 34.110388
# iteration 200 / 500: loss 3.982142
# iteration 300 / 500: loss 2.187568
# iteration 400 / 500: loss 2.103359
# iteration 0 / 500: loss 559.861269
# iteration 100 / 500: loss 32.390164
# iteration 200 / 500: loss 3.752661
# iteration 300 / 500: loss 2.123168
# iteration 400 / 500: loss 2.012599
# iteration 0 / 500: loss 571.730385
# iteration 100 / 500: loss 30.676266
# iteration 200 / 500: loss 3.544674
# iteration 300 / 500: loss 2.077756
# iteration 400 / 500: loss 2.112557
# iteration 0 / 500: loss 589.978097
# iteration 100 / 500: loss 29.094189
# iteration 200 / 500: loss 3.298786
# iteration 300 / 500: loss 2.098835
# iteration 400 / 500: loss 2.105457
# iteration 0 / 500: loss 606.338674
# iteration 100 / 500: loss 27.766571
# iteration 200 / 500: loss 3.205720
# iteration 300 / 500: loss 2.117945
# iteration 400 / 500: loss 2.042474
# iteration 0 / 500: loss 620.290333
# iteration 100 / 500: loss 26.354549
# iteration 200 / 500: loss 3.074626
# iteration 300 / 500: loss 2.110405
# iteration 400 / 500: loss 2.150784
# iteration 0 / 500: loss 644.788749
# iteration 100 / 500: loss 25.324355
# iteration 200 / 500: loss 2.911100
# iteration 300 / 500: loss 2.155915
# iteration 400 / 500: loss 2.045287
# iteration 0 / 500: loss 655.476151
# iteration 100 / 500: loss 23.808629
# iteration 200 / 500: loss 2.771713
# iteration 300 / 500: loss 2.114017
# iteration 400 / 500: loss 2.136320
# iteration 0 / 500: loss 660.820175
# iteration 100 / 500: loss 22.319987
# iteration 200 / 500: loss 2.753001
# iteration 300 / 500: loss 2.076043
# iteration 400 / 500: loss 2.136139
# iteration 0 / 500: loss 685.124374
# iteration 100 / 500: loss 21.349104
# iteration 200 / 500: loss 2.624692
# iteration 300 / 500: loss 2.107176
# iteration 400 / 500: loss 2.076016
# iteration 0 / 500: loss 704.410129
# iteration 100 / 500: loss 20.449926
# iteration 200 / 500: loss 2.615702
# iteration 300 / 500: loss 2.098251
# iteration 400 / 500: loss 2.022825
# iteration 0 / 500: loss 711.113876
# iteration 100 / 500: loss 19.189087
# iteration 200 / 500: loss 2.488971
# iteration 300 / 500: loss 2.067169
# iteration 400 / 500: loss 2.073250
# iteration 0 / 500: loss 733.201027
# iteration 100 / 500: loss 18.336689
# iteration 200 / 500: loss 2.366796
# iteration 300 / 500: loss 2.032568
# iteration 400 / 500: loss 2.065803
# iteration 0 / 500: loss 741.308002
# iteration 100 / 500: loss 17.207950
# iteration 200 / 500: loss 2.440965
# iteration 300 / 500: loss 2.144111
# iteration 400 / 500: loss 2.079905
# iteration 0 / 500: loss 762.070311
# iteration 100 / 500: loss 16.405621
# iteration 200 / 500: loss 2.378111
# iteration 300 / 500: loss 2.115595
# iteration 400 / 500: loss 2.039966
# iteration 0 / 500: loss 776.129234
# iteration 100 / 500: loss 15.564762
# iteration 200 / 500: loss 2.328492
# iteration 300 / 500: loss 2.070529
# iteration 400 / 500: loss 2.121760
# iteration 0 / 500: loss 384.195432
# iteration 100 / 500: loss 32.483910
# iteration 200 / 500: loss 4.534994
# iteration 300 / 500: loss 2.140850
# iteration 400 / 500: loss 2.064272
# iteration 0 / 500: loss 405.247139
# iteration 100 / 500: loss 30.883107
# iteration 200 / 500: loss 4.170706
# iteration 300 / 500: loss 2.184636
# iteration 400 / 500: loss 2.048282
# iteration 0 / 500: loss 415.556448
# iteration 100 / 500: loss 28.895234
# iteration 200 / 500: loss 3.749689
# iteration 300 / 500: loss 2.141671
# iteration 400 / 500: loss 2.036229
# iteration 0 / 500: loss 433.604089
# iteration 100 / 500: loss 27.268231
# iteration 200 / 500: loss 3.584586
# iteration 300 / 500: loss 2.122596
# iteration 400 / 500: loss 2.007721
# iteration 0 / 500: loss 457.283276
# iteration 100 / 500: loss 26.161323
# iteration 200 / 500: loss 3.284418
# iteration 300 / 500: loss 2.084595
# iteration 400 / 500: loss 2.036078
# iteration 0 / 500: loss 468.958871
# iteration 100 / 500: loss 24.422225
# iteration 200 / 500: loss 3.123103
# iteration 300 / 500: loss 2.022965
# iteration 400 / 500: loss 2.071695
# iteration 0 / 500: loss 483.265942
# iteration 100 / 500: loss 22.929104
# iteration 200 / 500: loss 2.991735
# iteration 300 / 500: loss 2.104063
# iteration 400 / 500: loss 2.057723
# iteration 0 / 500: loss 500.453922
# iteration 100 / 500: loss 21.573483
# iteration 200 / 500: loss 2.816293
# iteration 300 / 500: loss 2.107061
# iteration 400 / 500: loss 2.054885
# iteration 0 / 500: loss 515.510747
# iteration 100 / 500: loss 20.183350
# iteration 200 / 500: loss 2.698560
# iteration 300 / 500: loss 2.012309
# iteration 400 / 500: loss 2.048065
# iteration 0 / 500: loss 526.122865
# iteration 100 / 500: loss 18.720148
# iteration 200 / 500: loss 2.579335
# iteration 300 / 500: loss 2.114802
# iteration 400 / 500: loss 2.119816
# iteration 0 / 500: loss 550.113804
# iteration 100 / 500: loss 17.859271
# iteration 200 / 500: loss 2.507406
# iteration 300 / 500: loss 2.064838
# iteration 400 / 500: loss 2.058199
# iteration 0 / 500: loss 560.284572
# iteration 100 / 500: loss 16.564213
# iteration 200 / 500: loss 2.389859
# iteration 300 / 500: loss 2.106971
# iteration 400 / 500: loss 2.095795
# iteration 0 / 500: loss 577.111038
# iteration 100 / 500: loss 15.626598
# iteration 200 / 500: loss 2.354874
# iteration 300 / 500: loss 2.144218
# iteration 400 / 500: loss 2.081779
# iteration 0 / 500: loss 587.497758
# iteration 100 / 500: loss 14.571163
# iteration 200 / 500: loss 2.335885
# iteration 300 / 500: loss 1.992449
# iteration 400 / 500: loss 2.057667
# iteration 0 / 500: loss 604.272261
# iteration 100 / 500: loss 13.660674
# iteration 200 / 500: loss 2.330051
# iteration 300 / 500: loss 2.083389
# iteration 400 / 500: loss 2.086828
# iteration 0 / 500: loss 618.466041
# iteration 100 / 500: loss 12.733614
# iteration 200 / 500: loss 2.220987
# iteration 300 / 500: loss 2.096237
# iteration 400 / 500: loss 2.037853
# iteration 0 / 500: loss 633.858528
# iteration 100 / 500: loss 11.985268
# iteration 200 / 500: loss 2.227395
# iteration 300 / 500: loss 2.112880
# iteration 400 / 500: loss 2.127144
# iteration 0 / 500: loss 643.562082
# iteration 100 / 500: loss 11.107328
# iteration 200 / 500: loss 2.172106
# iteration 300 / 500: loss 2.080486
# iteration 400 / 500: loss 2.118987
# iteration 0 / 500: loss 665.768095
# iteration 100 / 500: loss 10.495066
# iteration 200 / 500: loss 2.186355
# iteration 300 / 500: loss 2.106284
# iteration 400 / 500: loss 2.101231
# iteration 0 / 500: loss 683.637955
# iteration 100 / 500: loss 9.959280
# iteration 200 / 500: loss 2.189849
# iteration 300 / 500: loss 2.097236
# iteration 400 / 500: loss 2.044460
# iteration 0 / 500: loss 691.177667
# iteration 100 / 500: loss 9.226355
# iteration 200 / 500: loss 2.210701
# iteration 300 / 500: loss 2.129797
# iteration 400 / 500: loss 2.053239
# iteration 0 / 500: loss 716.529666
# iteration 100 / 500: loss 8.833778
# iteration 200 / 500: loss 2.170486
# iteration 300 / 500: loss 2.037029
# iteration 400 / 500: loss 2.059065
# iteration 0 / 500: loss 726.988561
# iteration 100 / 500: loss 8.164342
# iteration 200 / 500: loss 2.114030
# iteration 300 / 500: loss 2.104076
# iteration 400 / 500: loss 2.045851
# iteration 0 / 500: loss 737.643076
# iteration 100 / 500: loss 7.687026
# iteration 200 / 500: loss 2.119083
# iteration 300 / 500: loss 2.049475
# iteration 400 / 500: loss 2.043924
# iteration 0 / 500: loss 759.393510
# iteration 100 / 500: loss 7.358484
# iteration 200 / 500: loss 2.198206
# iteration 300 / 500: loss 2.095386
# iteration 400 / 500: loss 2.076240
# iteration 0 / 500: loss 779.739368
# iteration 100 / 500: loss 6.913813
# iteration 200 / 500: loss 2.107826
# iteration 300 / 500: loss 2.088540
# iteration 400 / 500: loss 2.037102
# iteration 0 / 1500: loss 421.209030
# iteration 100 / 1500: loss 29.262443
# iteration 200 / 1500: loss 3.791458
# iteration 300 / 1500: loss 2.156713
# iteration 400 / 1500: loss 2.017609
# iteration 500 / 1500: loss 1.982076
# iteration 600 / 1500: loss 2.059650
# iteration 700 / 1500: loss 2.043419
# iteration 800 / 1500: loss 2.035006
# iteration 900 / 1500: loss 2.035865
# iteration 1000 / 1500: loss 2.078339
# iteration 1100 / 1500: loss 2.090685
# iteration 1200 / 1500: loss 2.146649
# iteration 1300 / 1500: loss 1.969567
# iteration 1400 / 1500: loss 2.044487
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.260367 val accuracy: 0.273000
# lr 1.000000e-07 reg 2.600000e+04 train accuracy: 0.271347 val accuracy: 0.264000
# lr 1.000000e-07 reg 2.700000e+04 train accuracy: 0.277714 val accuracy: 0.290000
# lr 1.000000e-07 reg 2.800000e+04 train accuracy: 0.273388 val accuracy: 0.266000
# lr 1.000000e-07 reg 2.900000e+04 train accuracy: 0.281653 val accuracy: 0.279000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.279857 val accuracy: 0.285000
# lr 1.000000e-07 reg 3.100000e+04 train accuracy: 0.277612 val accuracy: 0.277000
# lr 1.000000e-07 reg 3.200000e+04 train accuracy: 0.277980 val accuracy: 0.284000
# lr 1.000000e-07 reg 3.300000e+04 train accuracy: 0.285122 val accuracy: 0.280000
# lr 1.000000e-07 reg 3.400000e+04 train accuracy: 0.277796 val accuracy: 0.286000
# lr 1.000000e-07 reg 3.500000e+04 train accuracy: 0.282816 val accuracy: 0.302000
# lr 1.000000e-07 reg 3.600000e+04 train accuracy: 0.292082 val accuracy: 0.301000
# lr 1.000000e-07 reg 3.700000e+04 train accuracy: 0.293551 val accuracy: 0.304000
# lr 1.000000e-07 reg 3.800000e+04 train accuracy: 0.294857 val accuracy: 0.299000
# lr 1.000000e-07 reg 3.900000e+04 train accuracy: 0.287000 val accuracy: 0.283000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.291857 val accuracy: 0.282000
# lr 1.000000e-07 reg 4.100000e+04 train accuracy: 0.294449 val accuracy: 0.299000
# lr 1.000000e-07 reg 4.200000e+04 train accuracy: 0.301286 val accuracy: 0.311000
# lr 1.000000e-07 reg 4.300000e+04 train accuracy: 0.303020 val accuracy: 0.314000
# lr 1.000000e-07 reg 4.400000e+04 train accuracy: 0.303531 val accuracy: 0.315000
# lr 1.000000e-07 reg 4.500000e+04 train accuracy: 0.310449 val accuracy: 0.337000
# lr 1.000000e-07 reg 4.600000e+04 train accuracy: 0.305531 val accuracy: 0.307000
# lr 1.000000e-07 reg 4.700000e+04 train accuracy: 0.310327 val accuracy: 0.321000
# lr 1.000000e-07 reg 4.800000e+04 train accuracy: 0.309041 val accuracy: 0.318000
# lr 1.000000e-07 reg 4.900000e+04 train accuracy: 0.308163 val accuracy: 0.310000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.307918 val accuracy: 0.330000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.331490 val accuracy: 0.338000
# lr 2.000000e-07 reg 2.600000e+04 train accuracy: 0.339224 val accuracy: 0.345000
# lr 2.000000e-07 reg 2.700000e+04 train accuracy: 0.335673 val accuracy: 0.343000
# lr 2.000000e-07 reg 2.800000e+04 train accuracy: 0.340694 val accuracy: 0.353000
# lr 2.000000e-07 reg 2.900000e+04 train accuracy: 0.343531 val accuracy: 0.371000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.342653 val accuracy: 0.351000
# lr 2.000000e-07 reg 3.100000e+04 train accuracy: 0.338327 val accuracy: 0.359000
# lr 2.000000e-07 reg 3.200000e+04 train accuracy: 0.338347 val accuracy: 0.358000
# lr 2.000000e-07 reg 3.300000e+04 train accuracy: 0.338939 val accuracy: 0.359000
# lr 2.000000e-07 reg 3.400000e+04 train accuracy: 0.342122 val accuracy: 0.346000
# lr 2.000000e-07 reg 3.500000e+04 train accuracy: 0.337327 val accuracy: 0.347000
# lr 2.000000e-07 reg 3.600000e+04 train accuracy: 0.340816 val accuracy: 0.350000
# lr 2.000000e-07 reg 3.700000e+04 train accuracy: 0.335898 val accuracy: 0.351000
# lr 2.000000e-07 reg 3.800000e+04 train accuracy: 0.329837 val accuracy: 0.349000
# lr 2.000000e-07 reg 3.900000e+04 train accuracy: 0.345000 val accuracy: 0.357000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.330184 val accuracy: 0.343000
# lr 2.000000e-07 reg 4.100000e+04 train accuracy: 0.335000 val accuracy: 0.353000
# lr 2.000000e-07 reg 4.200000e+04 train accuracy: 0.332816 val accuracy: 0.354000
# lr 2.000000e-07 reg 4.300000e+04 train accuracy: 0.334469 val accuracy: 0.338000
# lr 2.000000e-07 reg 4.400000e+04 train accuracy: 0.333286 val accuracy: 0.348000
# lr 2.000000e-07 reg 4.500000e+04 train accuracy: 0.330061 val accuracy: 0.337000
# lr 2.000000e-07 reg 4.600000e+04 train accuracy: 0.329714 val accuracy: 0.346000
# lr 2.000000e-07 reg 4.700000e+04 train accuracy: 0.331020 val accuracy: 0.346000
# lr 2.000000e-07 reg 4.800000e+04 train accuracy: 0.328041 val accuracy: 0.346000
# lr 2.000000e-07 reg 4.900000e+04 train accuracy: 0.331082 val accuracy: 0.350000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.327837 val accuracy: 0.348000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.348592 val accuracy: 0.371000
# lr 3.000000e-07 reg 2.600000e+04 train accuracy: 0.346020 val accuracy: 0.352000
# lr 3.000000e-07 reg 2.700000e+04 train accuracy: 0.347510 val accuracy: 0.363000
# lr 3.000000e-07 reg 2.800000e+04 train accuracy: 0.344633 val accuracy: 0.361000
# lr 3.000000e-07 reg 2.900000e+04 train accuracy: 0.345082 val accuracy: 0.353000
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.341163 val accuracy: 0.349000
# lr 3.000000e-07 reg 3.100000e+04 train accuracy: 0.348612 val accuracy: 0.362000
# lr 3.000000e-07 reg 3.200000e+04 train accuracy: 0.340735 val accuracy: 0.359000
# lr 3.000000e-07 reg 3.300000e+04 train accuracy: 0.344939 val accuracy: 0.356000
# lr 3.000000e-07 reg 3.400000e+04 train accuracy: 0.337327 val accuracy: 0.364000
# lr 3.000000e-07 reg 3.500000e+04 train accuracy: 0.336714 val accuracy: 0.350000
# lr 3.000000e-07 reg 3.600000e+04 train accuracy: 0.339816 val accuracy: 0.362000
# lr 3.000000e-07 reg 3.700000e+04 train accuracy: 0.339714 val accuracy: 0.350000
# lr 3.000000e-07 reg 3.800000e+04 train accuracy: 0.332469 val accuracy: 0.350000
# lr 3.000000e-07 reg 3.900000e+04 train accuracy: 0.332551 val accuracy: 0.345000
# lr 3.000000e-07 reg 4.000000e+04 train accuracy: 0.332735 val accuracy: 0.347000
# lr 3.000000e-07 reg 4.100000e+04 train accuracy: 0.329041 val accuracy: 0.348000
# lr 3.000000e-07 reg 4.200000e+04 train accuracy: 0.333918 val accuracy: 0.346000
# lr 3.000000e-07 reg 4.300000e+04 train accuracy: 0.326612 val accuracy: 0.341000
# lr 3.000000e-07 reg 4.400000e+04 train accuracy: 0.327755 val accuracy: 0.346000
# lr 3.000000e-07 reg 4.500000e+04 train accuracy: 0.330163 val accuracy: 0.350000
# lr 3.000000e-07 reg 4.600000e+04 train accuracy: 0.324122 val accuracy: 0.342000
# lr 3.000000e-07 reg 4.700000e+04 train accuracy: 0.328857 val accuracy: 0.338000
# lr 3.000000e-07 reg 4.800000e+04 train accuracy: 0.315796 val accuracy: 0.327000
# lr 3.000000e-07 reg 4.900000e+04 train accuracy: 0.326898 val accuracy: 0.342000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.318755 val accuracy: 0.331000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.351224 val accuracy: 0.364000
# lr 4.000000e-07 reg 2.600000e+04 train accuracy: 0.351102 val accuracy: 0.365000
# lr 4.000000e-07 reg 2.700000e+04 train accuracy: 0.338898 val accuracy: 0.353000
# lr 4.000000e-07 reg 2.800000e+04 train accuracy: 0.338286 val accuracy: 0.356000
# lr 4.000000e-07 reg 2.900000e+04 train accuracy: 0.351061 val accuracy: 0.369000
# lr 4.000000e-07 reg 3.000000e+04 train accuracy: 0.344163 val accuracy: 0.357000
# lr 4.000000e-07 reg 3.100000e+04 train accuracy: 0.344388 val accuracy: 0.358000
# lr 4.000000e-07 reg 3.200000e+04 train accuracy: 0.343510 val accuracy: 0.362000
# lr 4.000000e-07 reg 3.300000e+04 train accuracy: 0.341204 val accuracy: 0.356000
# lr 4.000000e-07 reg 3.400000e+04 train accuracy: 0.339306 val accuracy: 0.364000
# lr 4.000000e-07 reg 3.500000e+04 train accuracy: 0.336306 val accuracy: 0.347000
# lr 4.000000e-07 reg 3.600000e+04 train accuracy: 0.339041 val accuracy: 0.355000
# lr 4.000000e-07 reg 3.700000e+04 train accuracy: 0.344673 val accuracy: 0.362000
# lr 4.000000e-07 reg 3.800000e+04 train accuracy: 0.330224 val accuracy: 0.347000
# lr 4.000000e-07 reg 3.900000e+04 train accuracy: 0.328735 val accuracy: 0.347000
# lr 4.000000e-07 reg 4.000000e+04 train accuracy: 0.337449 val accuracy: 0.335000
# lr 4.000000e-07 reg 4.100000e+04 train accuracy: 0.336000 val accuracy: 0.341000
# lr 4.000000e-07 reg 4.200000e+04 train accuracy: 0.334918 val accuracy: 0.348000
# lr 4.000000e-07 reg 4.300000e+04 train accuracy: 0.331796 val accuracy: 0.350000
# lr 4.000000e-07 reg 4.400000e+04 train accuracy: 0.333755 val accuracy: 0.352000
# lr 4.000000e-07 reg 4.500000e+04 train accuracy: 0.333041 val accuracy: 0.348000
# lr 4.000000e-07 reg 4.600000e+04 train accuracy: 0.327551 val accuracy: 0.339000
# lr 4.000000e-07 reg 4.700000e+04 train accuracy: 0.333612 val accuracy: 0.343000
# lr 4.000000e-07 reg 4.800000e+04 train accuracy: 0.317265 val accuracy: 0.332000
# lr 4.000000e-07 reg 4.900000e+04 train accuracy: 0.323939 val accuracy: 0.351000
# lr 4.000000e-07 reg 5.000000e+04 train accuracy: 0.325571 val accuracy: 0.349000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.349898 val accuracy: 0.358000
# lr 5.000000e-07 reg 2.600000e+04 train accuracy: 0.345980 val accuracy: 0.352000
# lr 5.000000e-07 reg 2.700000e+04 train accuracy: 0.348592 val accuracy: 0.372000
# lr 5.000000e-07 reg 2.800000e+04 train accuracy: 0.342714 val accuracy: 0.348000
# lr 5.000000e-07 reg 2.900000e+04 train accuracy: 0.338898 val accuracy: 0.357000
# lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.333184 val accuracy: 0.342000
# lr 5.000000e-07 reg 3.100000e+04 train accuracy: 0.337898 val accuracy: 0.347000
# lr 5.000000e-07 reg 3.200000e+04 train accuracy: 0.345327 val accuracy: 0.342000
# lr 5.000000e-07 reg 3.300000e+04 train accuracy: 0.332980 val accuracy: 0.346000
# lr 5.000000e-07 reg 3.400000e+04 train accuracy: 0.329347 val accuracy: 0.342000
# lr 5.000000e-07 reg 3.500000e+04 train accuracy: 0.344531 val accuracy: 0.347000
# lr 5.000000e-07 reg 3.600000e+04 train accuracy: 0.341714 val accuracy: 0.350000
# lr 5.000000e-07 reg 3.700000e+04 train accuracy: 0.340531 val accuracy: 0.351000
# lr 5.000000e-07 reg 3.800000e+04 train accuracy: 0.334143 val accuracy: 0.349000
# lr 5.000000e-07 reg 3.900000e+04 train accuracy: 0.338408 val accuracy: 0.356000
# lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.337286 val accuracy: 0.341000
# lr 5.000000e-07 reg 4.100000e+04 train accuracy: 0.326327 val accuracy: 0.334000
# lr 5.000000e-07 reg 4.200000e+04 train accuracy: 0.320959 val accuracy: 0.338000
# lr 5.000000e-07 reg 4.300000e+04 train accuracy: 0.325265 val accuracy: 0.336000
# lr 5.000000e-07 reg 4.400000e+04 train accuracy: 0.330918 val accuracy: 0.346000
# lr 5.000000e-07 reg 4.500000e+04 train accuracy: 0.327531 val accuracy: 0.336000
# lr 5.000000e-07 reg 4.600000e+04 train accuracy: 0.335714 val accuracy: 0.346000
# lr 5.000000e-07 reg 4.700000e+04 train accuracy: 0.326245 val accuracy: 0.351000
# lr 5.000000e-07 reg 4.800000e+04 train accuracy: 0.319204 val accuracy: 0.337000
# lr 5.000000e-07 reg 4.900000e+04 train accuracy: 0.321796 val accuracy: 0.336000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.314755 val accuracy: 0.321000
# best validation accuracy achieved during cross-validation: 0.351000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.363000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$ True
#
#
# $\color{blue}{\textit Your Explanation:}$ The SVM loss is the sum of the per-datapoint loss over all training examples. However, the Softmax classifier loss concerns log probabilities which will change.

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
